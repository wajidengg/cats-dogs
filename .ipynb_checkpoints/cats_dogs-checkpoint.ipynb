# %% [markdown]
# ## Gradio Pets

# %%
#|default_exp app
! pip install -q gradio

# %%
# !pip install -Uqq fastai

# %%
#|export
from fastai.vision.all import *
import gradio as gr

def is_cat(x): return x[0].isupper()

# %%
path = untar_data(URLs.PETS)/'images'

dls = ImageDataLoaders.from_name_func('.',
    get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_cat,
    item_tfms=Resize(192))
# Out:
# Downloading a new version of this dataset...
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='811712512' class='' max='811706944' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [811712512/811706944 03:52&lt;00:00]
#     </div>

# %%
dls.show_batch()

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# /home/wajid/mambaforge/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/wajid/mambaforge/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/wajid/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.194946</td>
#       <td>0.065907</td>
#       <td>0.017591</td>
#       <td>05:57</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.081902</td>
#       <td>0.041516</td>
#       <td>0.014885</td>
#       <td>09:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.040769</td>
#       <td>0.029236</td>
#       <td>0.006766</td>
#       <td>09:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.020371</td>
#       <td>0.032567</td>
#       <td>0.007442</td>
#       <td>09:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.export('model.pkl')

# %%
im = PILImage.create('dog.jfif')
im.thumbnail((192,192))
im
# Out:
# PILImage mode=RGB size=192x149

# %%
#|export
learn = load_learner('model.pkl')

# %%
learn.predict(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('False', TensorBase(0), TensorBase([9.9956e-01, 4.3661e-04]))

# %%
#|export
categories = ('Dog', 'Cat')

def classify_image(img):
    pred,idx,probs = learn.predict(img)
    return dict(zip(categories, map(float,probs)))

# %%
classify_image(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'Dog': 0.9995633959770203, 'Cat': 0.00043661377276293933}

# %%
#|export
image = gr.inputs.Image(shape=(192, 192))
label = gr.outputs.Label()
examples = ['dog.jfif', 'cat.jfif', 'dunno.jfif']

intf = gr.Interface(fn=classify_image, inputs=image, outputs=label, examples=examples)
intf.launch(inline=False, share=True)
# Out:
# /home/wajid/mambaforge/lib/python3.10/site-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /home/wajid/mambaforge/lib/python3.10/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /home/wajid/mambaforge/lib/python3.10/site-packages/gradio/outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# /home/wajid/mambaforge/lib/python3.10/site-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://ee578dfe-34f7-4bc0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# !pip install nbdev
# Out:
# Requirement already satisfied: nbdev in /home/wajid/mambaforge/lib/python3.10/site-packages (2.3.11)
# Requirement already satisfied: astunparse in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (1.6.3)
# Requirement already satisfied: asttokens in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (2.2.1)
# Requirement already satisfied: ghapi>=1.0.3 in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (1.0.3)
# Requirement already satisfied: execnb>=0.1.4 in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (0.1.4)
# Requirement already satisfied: watchdog in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (2.2.1)
# Requirement already satisfied: fastcore>=1.5.27 in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (1.5.28)
# Requirement already satisfied: PyYAML in /home/wajid/mambaforge/lib/python3.10/site-packages (from nbdev) (6.0)
# Requirement already satisfied: ipython in /home/wajid/mambaforge/lib/python3.10/site-packages (from execnb>=0.1.4->nbdev) (8.9.0)
# Requirement already satisfied: pip in /home/wajid/mambaforge/lib/python3.10/site-packages (from fastcore>=1.5.27->nbdev) (22.3.1)
# Requirement already satisfied: packaging in /home/wajid/mambaforge/lib/python3.10/site-packages (from fastcore>=1.5.27->nbdev) (23.0)
# Requirement already satisfied: six in /home/wajid/mambaforge/lib/python3.10/site-packages (from asttokens->nbdev) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/wajid/mambaforge/lib/python3.10/site-packages (from astunparse->nbdev) (0.38.4)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (3.0.36)
# Requirement already satisfied: pickleshare in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.7.5)
# Requirement already satisfied: backcall in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.2.0)
# Requirement already satisfied: stack-data in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (5.9.0)
# Requirement already satisfied: matplotlib-inline in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (2.14.0)
# Requirement already satisfied: jedi>=0.16 in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (4.8.0)
# Requirement already satisfied: decorator in /home/wajid/mambaforge/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/wajid/mambaforge/lib/python3.10/site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/wajid/mambaforge/lib/python3.10/site-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev) (0.7.0)
# Requirement already satisfied: wcwidth in /home/wajid/mambaforge/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->execnb>=0.1.4->nbdev) (0.2.6)
# Requirement already satisfied: pure-eval in /home/wajid/mambaforge/lib/python3.10/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/wajid/mambaforge/lib/python3.10/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (1.2.0)

# %%
import nbdev

# %%
from nbdev.export import nb_export
nb_export('cats_dogs.ipynb', '.')

# %%
# !cat app.py
# Out:
# # AUTOGENERATED! DO NOT EDIT! File to edit: cats_dogs.ipynb.
#
# # %% auto 0
# __all__ = ['learn', 'categories', 'image', 'label', 'examples', 'intf', 'is_cat', 'classify_image']
#
# # %% cats_dogs.ipynb 3
# from fastai.vision.all import *
# import gradio as gr
#
# def is_cat(x): return x[0].isupper()
#
# # %% cats_dogs.ipynb 9
# learn = load_learner('model.pkl')
#
# # %% cats_dogs.ipynb 11
# categories = ('Dog', 'Cat')
#
# def classify_image(img):
#     pred,idx,probs = learn.predict(img)
#     return dict(zip(categories, map(float,probs)))
#
# # %% cats_dogs.ipynb 14
# image = gr.inputs.Image(shape=(192, 192))
# label = gr.outputs.Label()
# examples = ['dog.jfif', 'cat.jfif', 'dunno.jfif']
#
# intf = gr.Interface(fn=classify_image, inputs=image, outputs=label, examples=examples)
# intf.launch(inline=False, share=True)
